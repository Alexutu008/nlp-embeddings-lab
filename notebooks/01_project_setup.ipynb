# %%
print('hello embeddings lab')
# Out:
# hello embeddings lab

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
SRC_PATH = PROJECT_ROOT / 'src'

if str(SRC_PATH) not in sys.path:
    sys.path.append(str(SRC_PATH))

# %%
from core.preprocessing import simple_tokeninze

text = 'This is a simple test for tokenization.'
print(simple_tokeninze(text))
# Out:
# ['this', 'is', 'a', 'simple', 'test', 'for', 'tokenization']

# %%
from core.preprocessing import simple_tokeninze
from core.vocab import Vocabulary

texts = [
    'Studiem NLP',
    'Ion e gog',
]

tokenized = [simple_tokeninze(text) for text in texts]
print(tokenized)
# Out:
# [['studiem', 'nlp'], ['ion', 'e', 'gog']]

# %%
vocab = Vocabulary(min_freq=1)
vocab.fit(tokenized)

print(vocab.stoi)
print(vocab.encode(tokenized[0]))
# Out:
# {'<pad>': 0, '<unk>': 1, 'studiem': 2, 'nlp': 3, 'ion': 4, 'e': 5, 'gog': 6}
# [2, 3]
